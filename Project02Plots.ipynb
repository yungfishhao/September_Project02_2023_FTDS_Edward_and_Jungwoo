# %%
import numpy as np
import pandas as pd

# %%
raw_data = [['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '216kcal', '216kcal', 'Protein', '5.6g', '5.6g', 'Total Fat', '5.5g', '5.5g', 'Saturated Fat', '1.2g', '1.2g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '35.7g', '35.7g', 'Sugars', '8.4g', '8.4g', 'Sodium', '375mg', '375mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '323kcal', '216kcal', 'Protein', '8.4g', '5.6g', 'Total Fat', '8.2g', '5.5g', 'Saturated Fat', '1.7g', '1.2g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '53.5g', '35.7g', 'Sugars', '12.6g', '8.4g', 'Sodium', '563mg', '375mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '597kcal', '238kcal', 'Protein', '23.3g', '9.3g', 'Total Fat', '38.5g', '15.3g', 'Saturated Fat', '10g', '4g', 'Trans Fat', '0.8g', '0.3g', 'Carbohydrates', '38.2g', '15.2g', 'Sugars', '3.1g', '1.3g', 'Sodium', '1063mg', '424mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '637kcal', '259kcal', 'Protein', '15.5g', '6.3g', 'Total Fat', '34.2g', '13.9g', 'Saturated Fat', '8.3g', '3.4g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '66.3g', '27g', 'Sugars', '13.2g', '5.4g', 'Sodium', '1193mg', '485mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '813kcal', '228kcal', 'Protein', '28.9g', '8.1g', 'Total Fat', '44g', '12.3g', 'Saturated Fat', '11.2g', '3.1g', 'Trans Fat', '0.8g', '0g', 'Carbohydrates', '74g', '20.8g', 'Sugars', '11.5g', '3.2g', 'Sodium', '1438mg', '404mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '335kcal', '59kcal', 'Protein', '25.5g', '4.5g', 'Total Fat', '7.2g', '1.3g', 'Saturated Fat', '2.2g', '0.4g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '43.1g', '7.6g', 'Sugars', '4.9g', '0.9g', 'Sodium', '1862mg', '330mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '435kcal', '76kcal', 'Protein', '19.6g', '3.4g', 'Total Fat', '21.4g', '3.7g', 'Saturated Fat', '7.2g', '1.3g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '41.5g', '7.3g', 'Sugars', '5.1g', '0.9g', 'Sodium', '1672mg', '293mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '452kcal', '79kcal', 'Protein', '20.5g', '3.6g', 'Total Fat', '22.9g', '4g', 'Saturated Fat', '7.8g', '1.4g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '41.8g', '7.3g', 'Sugars', '4.9g', '0.9g', 'Sodium', '1714mg', '300mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '347kcal', '61kcal', 'Protein', '26.1g', '4.6g', 'Total Fat', '7.4g', '1.3g', 'Saturated Fat', '2.5g', '0.4g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '44.9g', '7.9g', 'Sugars', '4.7g', '0.8g', 'Sodium', '1255mg', '222mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '447kcal', '78kcal', 'Protein', '20.2g', '3.5g', 'Total Fat', '21.5g', '3.8g', 'Saturated Fat', '7.5g', '1.3g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '43.3g', '7.6g', 'Sugars', '4.9g', '0.9g', 'Sodium', '1064mg', '186mg'], ['Nutritional Information', 'Per Serving', 'Per 100g/mL*', 'Energy', '469kcal', '82kcal', 'Protein', '20.9g', '3.7g', 'Total Fat', '23.9g', '4.2g', 'Saturated Fat', '8.2g', '1.4g', 'Trans Fat', '0g', '0g', 'Carbohydrates', '43.2g', '7.5g', 'Sugars', '4.8g', '0.8g', 'Sodium', '1096mg', '192mg']]

items = [
     "hotcake-2pcs",
     "hotcakes-3pcs",
     "deluxe-breakfast",
     "hotcakes-with-sausage-hash-browns",
     "jumbo-breakfast",
     "grilled-chicken-twisty-pasta-original",
     "ham-n-egg-twisty-pasta-original",
     "sausage-n-egg-twisty-pasta-original",
     "grilled-chicken-twisty-pasta-tonkotsu",
     "ham-n-egg-twisty-pasta-tonkotsu",
     "sausage-n-egg-twisty-pasta-tonkotsu"
]

some_data = pd.DataFrame(raw_data, index=items)
some_data
# Out:
#                                                             0            1   \
# hotcake-2pcs                           Nutritional Information  Per Serving
# hotcakes-3pcs                          Nutritional Information  Per Serving
# deluxe-breakfast                       Nutritional Information  Per Serving
# hotcakes-with-sausage-hash-browns      Nutritional Information  Per Serving
# jumbo-breakfast                        Nutritional Information  Per Serving
# grilled-chicken-twisty-pasta-original  Nutritional Information  Per Serving
# ham-n-egg-twisty-pasta-original        Nutritional Information  Per Serving
# sausage-n-egg-twisty-pasta-original    Nutritional Information  Per Serving
# grilled-chicken-twisty-pasta-tonkotsu  Nutritional Information  Per Serving
# ham-n-egg-twisty-pasta-tonkotsu        Nutritional Information  Per Serving
# sausage-n-egg-twisty-pasta-tonkotsu    Nutritional Information  Per Serving
#
# ...

# %%
some_data.drop(columns=some_data.columns[0:3], inplace=True)
some_data.drop(columns=some_data.columns[0::3], inplace=True)
some_data.drop(columns=some_data.columns[1::2], inplace=True)
some_data
# Out:
#                                             4      7      10     13    16  \
# hotcake-2pcs                           216kcal   5.6g   5.5g   1.2g    0g
# hotcakes-3pcs                          323kcal   8.4g   8.2g   1.7g    0g
# deluxe-breakfast                       597kcal  23.3g  38.5g    10g  0.8g
# hotcakes-with-sausage-hash-browns      637kcal  15.5g  34.2g   8.3g    0g
# jumbo-breakfast                        813kcal  28.9g    44g  11.2g  0.8g
# grilled-chicken-twisty-pasta-original  335kcal  25.5g   7.2g   2.2g    0g
# ham-n-egg-twisty-pasta-original        435kcal  19.6g  21.4g   7.2g    0g
# sausage-n-egg-twisty-pasta-original    452kcal  20.5g  22.9g   7.8g    0g
# grilled-chicken-twisty-pasta-tonkotsu  347kcal  26.1g   7.4g   2.5g    0g
# ham-n-egg-twisty-pasta-tonkotsu        447kcal  20.2g  21.5g   7.5g    0g
# sausage-n-egg-twisty-pasta-tonkotsu    469kcal  20.9g  23.9g   8.2g    0g
#
#                                           19     22      25
# ...

# %%
some_data = some_data.rename(columns={4: 'Energy', 7: 'Protein', 10:'Total Fat', 13:'Saturated Fat', 16:'Trans Fat', 19:'Carbohydrates', 22:'Sugars', 25:'Sodium'})
some_data
# Out:
#                                         Energy Protein Total Fat  \
# hotcake-2pcs                           216kcal    5.6g      5.5g
# hotcakes-3pcs                          323kcal    8.4g      8.2g
# deluxe-breakfast                       597kcal   23.3g     38.5g
# hotcakes-with-sausage-hash-browns      637kcal   15.5g     34.2g
# jumbo-breakfast                        813kcal   28.9g       44g
# grilled-chicken-twisty-pasta-original  335kcal   25.5g      7.2g
# ham-n-egg-twisty-pasta-original        435kcal   19.6g     21.4g
# sausage-n-egg-twisty-pasta-original    452kcal   20.5g     22.9g
# grilled-chicken-twisty-pasta-tonkotsu  347kcal   26.1g      7.4g
# ham-n-egg-twisty-pasta-tonkotsu        447kcal   20.2g     21.5g
# sausage-n-egg-twisty-pasta-tonkotsu    469kcal   20.9g     23.9g
#
#                                       Saturated Fat Trans Fat Carbohydrates  \
# hotcake-2pcs                                   1.2g        0g         35.7g
# ...

# %%
some_data['Energy'] = some_data['Energy'].transform(func = lambda x: x[:-4])
some_data['Protein'] = some_data['Protein'].transform(func = lambda x: x[:-1])
some_data['Total Fat'] = some_data['Total Fat'].transform(func = lambda x: x[:-1])
some_data['Saturated Fat'] = some_data['Saturated Fat'].transform(func = lambda x: x[:-1])
some_data['Trans Fat'] = some_data['Trans Fat'].transform(func = lambda x: x[:-1])
some_data['Carbohydrates'] = some_data['Carbohydrates'].transform(func = lambda x: x[:-1])
some_data['Sugars'] = some_data['Sugars'].transform(func = lambda x: x[:-1])
some_data['Sodium'] = some_data['Sodium'].transform(func = lambda x: x[:-2])

# %%
some_data['Energy'] = some_data['Energy'].astype(float)
some_data['Protein'] = some_data['Protein'].astype(float)
some_data['Total Fat'] = some_data['Total Fat'].astype(float)
some_data['Saturated Fat'] = some_data['Saturated Fat'].astype(float)
some_data['Trans Fat'] = some_data['Trans Fat'].astype(float)
some_data['Carbohydrates'] = some_data['Carbohydrates'].astype(float)
some_data['Sugars'] = some_data['Sugars'].astype(float)
some_data['Sodium'] = some_data['Sodium'].astype(float)

# %%
some_data.rename(columns={'Energy': 'Energy (kcal)',
                                                  'Protein': 'Protein (g)',
                                                  'Total Fat': 'Total Fat (g)',
                                                  'Saturated Fat': 'Saturated Fat (g)',
                                                  'Trans Fat':'Trans Fat (g)',
                                                  'Carbohydrates':'Carbohydrates (g)',
                                                  'Sugars':'Sugars (g)',
                                                  'Sodium':'Sodium (mg)'}, inplace=True)

# %%
some_data.dtypes
# Out:
# Energy (kcal)        float64
# Protein (g)          float64
# Total Fat (g)        float64
# Saturated Fat (g)    float64
# Trans Fat (g)        float64
# Carbohydrates (g)    float64
# Sugars (g)           float64
# Sodium (mg)          float64
# dtype: object

# %%
some_data
# Out:
#                                        Energy (kcal)  Protein (g)  \
# hotcake-2pcs                                   216.0          5.6
# hotcakes-3pcs                                  323.0          8.4
# deluxe-breakfast                               597.0         23.3
# hotcakes-with-sausage-hash-browns              637.0         15.5
# jumbo-breakfast                                813.0         28.9
# grilled-chicken-twisty-pasta-original          335.0         25.5
# ham-n-egg-twisty-pasta-original                435.0         19.6
# sausage-n-egg-twisty-pasta-original            452.0         20.5
# grilled-chicken-twisty-pasta-tonkotsu          347.0         26.1
# ham-n-egg-twisty-pasta-tonkotsu                447.0         20.2
# sausage-n-egg-twisty-pasta-tonkotsu            469.0         20.9
#
#                                        Total Fat (g)  Saturated Fat (g)  \
# hotcake-2pcs                                     5.5                1.2
# ...

# %%
some_data.to_csv('McDonalds_HK_Breakfast_Nutritional_Data.csv')
